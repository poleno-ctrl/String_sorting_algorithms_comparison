# %%
import pandas as pd
import seaborn as sns

sns.set_theme(style="whitegrid")

df = pd.read_csv('benchmark_results.csv')

sns.relplot(data=df, x='Size', y='Time_us', hue='Algorithm', col='DataType', kind='line', marker='o')

sns.relplot(data=df, x='Size', y='Comparisons', hue='Algorithm', col='DataType', kind='line', marker='o')
